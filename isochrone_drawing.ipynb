# %%
import geopandas as gpd
import osmnx as ox
from shapely.geometry import Point

# %%
import osmnx as ox

print(f"OSMnx version: {ox.__version__}")
# Out:
# OSMnx version: 2.0.1

# %%
import osmnx as ox
import os

# Specify the place name (Oregon)
place_name = "Oregon, USA"

# Download the graph
graph = ox.graph_from_place(place_name, network_type="drive")  # You can change network_type

graph_proj = ox.project_graph(graph)

# Get the path to your Downloads folder
downloads_path = os.path.join(os.path.expanduser("~"), "Downloads")

# Create the full file path
file_path = os.path.join(downloads_path, "oregon_drive_network_projected.graphml")

# Save the graph as a GraphML file
ox.save_graphml(graph_proj, filepath=file_path)

print(f"Projected GraphML file saved to: {file_path}")
# Out:
# C:\Users\weckero\AppData\Roaming\Python\Python311\site-packages\osmnx\_overpass.py:267: UserWarning: This area is 115 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)
# Projected GraphML file saved to: C:\Users\weckero\Downloads\oregon_drive_network_projected.graphml

# %%
import osmnx as ox
import geopandas as gpd

# Load the GraphML file
graph = ox.load_graphml(filepath= downloads_path + "/oregon_drive_network_projected.graphml") #replace with your file name.
graph_proj = ox.project_graph(graph)

# %%
#Example of loading point data.
basefolder = "C:/Users/weckero/Documents/Tobackup/"

points_gdf = gpd.read_file(basefolder + "people_points.shp") #replace with your file name.
#points_gdf = points_gdf.to_crs(graph_proj.graph_crs) #project the point data.

# %%
import osmnx as ox
import geopandas as gpd
import os
import numpy as np
import networkx as nx
from shapely.geometry import Polygon, MultiPolygon
from shapely.ops import unary_union
import pandas as pd

# 1. Load the GraphML file
downloads_path = os.path.join(os.path.expanduser("~"), "Downloads")
documents_path = os.path.join(os.path.expanduser("~"), "Documents")
graph = ox.load_graphml(os.path.join(downloads_path, "oregon_drive_network_projected.graphml"))
graph_proj = ox.project_graph(graph)

# 2. Load Point Data
basefolder = "C:/Users/weckero/Documents/Tobackup/"
points_gdf = gpd.read_file(documents_path + "clipped_tester.shp")
points_gdf = points_gdf.to_crs(graph_proj.graph['crs'])

# 3. Find nearest nodes
# Check if nearest_nodes exists in the current version
if hasattr(ox, 'get_nearest_nodes'):
    nearest_nodes = ox.get_nearest_nodes(
        G=graph_proj,
        X=points_gdf.geometry.x,
        Y=points_gdf.geometry.y
    )
elif hasattr(ox.distance, 'nearest_nodes'):
    nearest_nodes = ox.distance.nearest_nodes(
        G=graph_proj,
        X=points_gdf.geometry.x,
        Y=points_gdf.geometry.y
    )
else:
    # Manual implementation as fallback
    nearest_nodes = []
    for idx, point in points_gdf.iterrows():
        nearest = None
        min_dist = float('inf')
        for node, data in graph_proj.nodes(data=True):
            dist = ((data['x'] - point.geometry.x) ** 2 + 
                    (data['y'] - point.geometry.y) ** 2) ** 0.5
            if dist < min_dist:
                nearest = node
                min_dist = dist
        nearest_nodes.append(nearest)
        print(f"Found nearest node {nearest} for point {idx+1}/{len(points_gdf)}")

# 4. Check if travel_time exists in the graph
sample_edge = list(graph_proj.edges(data=True))[0][2]
if 'travel_time' not in sample_edge:
    print("Adding travel time to graph edges...")
    if 'length' in sample_edge and 'speed_kph' in sample_edge:
        # If the graph has length and speed information
        for u, v, data in graph_proj.edges(data=True):
            data['travel_time'] = data['length'] / (data['speed_kph'] * 1000 / 3600)
    else:
        # If not, use default speed (30 km/h if not available)
        if hasattr(ox, 'add_edge_speeds'):
            graph_proj = ox.add_edge_speeds(graph_proj)
        else:
            for u, v, data in graph_proj.edges(data=True):
                data['speed_kph'] = 30  # Default speed
                
        if hasattr(ox, 'add_edge_travel_times'):
            graph_proj = ox.add_edge_travel_times(graph_proj)
        else:
            for u, v, data in graph_proj.edges(data=True):
                if 'length' in data and 'speed_kph' in data:
                    data['travel_time'] = data['length'] / (data['speed_kph'] * 1000 / 3600)
                else:
                    # Default 3 minutes per edge if we can't calculate
                    data['travel_time'] = 180

# 5. Generate Isochrones
travel_time = 3600  # 1 hour in seconds
isochrones_list = []

for i, node in enumerate(nearest_nodes):
    try:
        print(f"Processing node {i+1}/{len(nearest_nodes)}: {node}")
        
        # Calculate shortest paths using networkx directly - compatible with all versions
        try:
            # Get all nodes that can be reached within travel_time
            reachable_nodes = []
            # Use networkx's single_source_dijkstra_path_length
            lengths = nx.single_source_dijkstra_path_length(
                G=graph_proj, 
                source=node, 
                cutoff=travel_time, 
                weight='travel_time'
            )
            
            reachable_nodes = list(lengths.keys())
            
            if not reachable_nodes:
                print(f"No nodes within travel time for node {node}")
                continue
                
            # Get coordinates for reachable nodes
            node_points = []
            for n in reachable_nodes:
                try:
                    node_points.append((graph_proj.nodes[n]['x'], graph_proj.nodes[n]['y']))
                except KeyError:
                    # Skip nodes without coordinates
                    continue
            
            if len(node_points) < 3:
                print(f"Not enough points ({len(node_points)}) to create polygon for node {node}")
                continue
                
            # Create a convex hull for the isochrone
            try:
                from scipy.spatial import ConvexHull
                hull = ConvexHull(node_points)
                polygon_points = [node_points[i] for i in hull.vertices]
                
                # Create Polygon
                isochrone_polygon = Polygon(polygon_points)
                
                # If the polygon is valid, add it to our results
                if isochrone_polygon.is_valid:
                    # Copy attributes from the original point
                    point_info = {}
                    if i < len(points_gdf):
                        for col in points_gdf.columns:
                            if col != 'geometry':
                                point_info[col] = points_gdf.iloc[i][col]
                    
                    isochrone_gdf = gpd.GeoDataFrame(
                        {**point_info, 'node_id': str(node), 'travel_time_mins': travel_time/60},
                        geometry=[isochrone_polygon], 
                        crs=graph_proj.graph['crs']
                    )
                    
                    isochrones_list.append(isochrone_gdf)
                    print(f"Successfully created isochrone for node {node}")
                else:
                    print(f"Created invalid polygon for node {node}")
                
            except Exception as e:
                print(f"Error creating polygon for node {node}: {e}")
                    
        except Exception as e:
            print(f"Error calculating paths for node {node}: {e}")
            
    except Exception as e:
        print(f"Error processing node {node}: {e}")

# Combine all isochrones into a single GeoDataFrame
if isochrones_list:
    try:
        isochrones_gdf = pd.concat(isochrones_list)
        
        # 6. Save the isochrones
        isochrones_output = os.path.join(basefolder, "isochrones_points.shp")
        isochrones_gdf.to_file(isochrones_output)
        print(f"Saved {len(isochrones_list)} isochrones to {isochrones_output}")
    except Exception as e:
        print(f"Error saving isochrones: {e}")
        # Try to save individually
        for i, iso_gdf in enumerate(isochrones_list):
            try:
                iso_output = os.path.join(basefolder, f"isochrone_{i}.shp")
                iso_gdf.to_file(iso_output)
                print(f"Saved individual isochrone to {iso_output}")
            except Exception as e2:
                print(f"Could not save isochrone {i}: {e2}")
else:
    print("No isochrones were created successfully.")
# Out:
# Adding travel time to graph edges...
# Processing node 1/4953: 36944611
# Error creating polygon for node 36944611: If using all scalar values, you must pass an index
# Processing node 2/4953: 12177744664
# Error creating polygon for node 12177744664: If using all scalar values, you must pass an index
# Processing node 3/4953: 4854467950
# Error creating polygon for node 4854467950: If using all scalar values, you must pass an index
# Processing node 4/4953: 7058457949
# Error creating polygon for node 7058457949: If using all scalar values, you must pass an index
# Processing node 5/4953: 7058457949
# Error creating polygon for node 7058457949: If using all scalar values, you must pass an index
# Processing node 6/4953: 7058457949
# Error creating polygon for node 7058457949: If using all scalar values, you must pass an index
# Processing node 7/4953: 4854467950
# Error creating polygon for node 4854467950: If using all scalar values, you must pass an index
# Processing node 8/4953: 36959155
# Error creating polygon for node 36959155: If using all scalar values, you must pass an index
# Processing node 9/4953: 36959155
# Error creating polygon for node 36959155: If using all scalar values, you must pass an index
# Processing node 10/4953: 36959155
# Error creating polygon for node 36959155: If using all scalar values, you must pass an index
# Processing node 11/4953: 36959155
# Error creating polygon for node 36959155: If using all scalar values, you must pass an index
# Processing node 12/4953: 36959155
# Error creating polygon for node 36959155: If using all scalar values, you must pass an index
# Processing node 13/4953: 36959155
# Error creating polygon for node 36959155: If using all scalar values, you must pass an index
# Processing node 14/4953: 36921184
# Error creating polygon for node 36921184: If using all scalar values, you must pass an index
# Processing node 15/4953: 10181880066
# Error creating polygon for node 10181880066: If using all scalar values, you must pass an index
# Processing node 16/4953: 10181880066
# Error creating polygon for node 10181880066: If using all scalar values, you must pass an index
# Processing node 17/4953: 36936470
# Error creating polygon for node 36936470: If using all scalar values, you must pass an index
# Processing node 18/4953: 36936470
# Error creating polygon for node 36936470: If using all scalar values, you must pass an index
# Processing node 19/4953: 36936470
# Error creating polygon for node 36936470: If using all scalar values, you must pass an index
# Processing node 20/4953: 36936470
# Error creating polygon for node 36936470: If using all scalar values, you must pass an index
# Processing node 21/4953: 36936470
# Error creating polygon for node 36936470: If using all scalar values, you must pass an index
# Processing node 22/4953: 36936470
# Error creating polygon for node 36936470: If using all scalar values, you must pass an index
# Processing node 23/4953: 36936470
# Error creating polygon for node 36936470: If using all scalar values, you must pass an index
# Processing node 24/4953: 11918887669
# Error creating polygon for node 11918887669: If using all scalar values, you must pass an index
# Processing node 25/4953: 11918887669
# Error creating polygon for node 11918887669: If using all scalar values, you must pass an index
# Processing node 26/4953: 11918887669
# Error creating polygon for node 11918887669: If using all scalar values, you must pass an index
# Processing node 27/4953: 11918887669
# Error creating polygon for node 11918887669: If using all scalar values, you must pass an index
# Processing node 28/4953: 11918887669
# Error creating polygon for node 11918887669: If using all scalar values, you must pass an index
# Processing node 29/4953: 11918887669
# Error creating polygon for node 11918887669: If using all scalar values, you must pass an index
# Processing node 30/4953: 11918887669
# Error creating polygon for node 11918887669: If using all scalar values, you must pass an index
# Processing node 31/4953: 11918887669
# Error creating polygon for node 11918887669: If using all scalar values, you must pass an index
# Processing node 32/4953: 36934606
# Error creating polygon for node 36934606: If using all scalar values, you must pass an index
# Processing node 33/4953: 36987804
# Error creating polygon for node 36987804: If using all scalar values, you must pass an index
# Processing node 34/4953: 36944611
# Error creating polygon for node 36944611: If using all scalar values, you must pass an index
# Processing node 35/4953: 36944611
# Error creating polygon for node 36944611: If using all scalar values, you must pass an index
# Processing node 36/4953: 36944611
# Error creating polygon for node 36944611: If using all scalar values, you must pass an index
# Processing node 37/4953: 36944611
# Error creating polygon for node 36944611: If using all scalar values, you must pass an index
# Processing node 38/4953: 36981870
# Error creating polygon for node 36981870: If using all scalar values, you must pass an index
# Processing node 39/4953: 4854467950
# Error creating polygon for node 4854467950: If using all scalar values, you must pass an index
# Processing node 40/4953: 36935380
# Error creating polygon for node 36935380: If using all scalar values, you must pass an index
# Processing node 41/4953: 36934576
# Error creating polygon for node 36934576: If using all scalar values, you must pass an index
# Processing node 42/4953: 36936458
# Error creating polygon for node 36936458: If using all scalar values, you must pass an index
# Processing node 43/4953: 36936458
# Error creating polygon for node 36936458: If using all scalar values, you must pass an index
# Processing node 44/4953: 36921173
# Error creating polygon for node 36921173: If using all scalar values, you must pass an index
# Processing node 45/4953: 36921173
# Error creating polygon for node 36921173: If using all scalar values, you must pass an index
# Processing node 46/4953: 36921173
# Error creating polygon for node 36921173: If using all scalar values, you must pass an index
# Processing node 47/4953: 36921173
# Error creating polygon for node 36921173: If using all scalar values, you must pass an index
# Processing node 48/4953: 36921173
# Error creating polygon for node 36921173: If using all scalar values, you must pass an index
# Processing node 49/4953: 36921173
# Error creating polygon for node 36921173: If using all scalar values, you must pass an index
# Processing node 50/4953: 36946270
# Error creating polygon for node 36946270: If using all scalar values, you must pass an index
# Processing node 51/4953: 36946270
# Error creating polygon for node 36946270: If using all scalar values, you must pass an index
# Processing node 52/4953: 36946270
# Error creating polygon for node 36946270: If using all scalar values, you must pass an index
# Processing node 53/4953: 36946270
# Error creating polygon for node 36946270: If using all scalar values, you must pass an index
# Processing node 54/4953: 36946270
# Error creating polygon for node 36946270: If using all scalar values, you must pass an index
# Processing node 55/4953: 36946270
# Error creating polygon for node 36946270: If using all scalar values, you must pass an index
# Processing node 56/4953: 36946270
# Error creating polygon for node 36946270: If using all scalar values, you must pass an index
# Processing node 57/4953: 36946270
# Error creating polygon for node 36946270: If using all scalar values, you must pass an index
# Processing node 58/4953: 36946270
# Error creating polygon for node 36946270: If using all scalar values, you must pass an index
# Processing node 59/4953: 36946270
# Error creating polygon for node 36946270: If using all scalar values, you must pass an index
# Processing node 60/4953: 36946270
# Error creating polygon for node 36946270: If using all scalar values, you must pass an index
# Processing node 61/4953: 36946270
# Error creating polygon for node 36946270: If using all scalar values, you must pass an index
# Processing node 62/4953: 36946270
# Error creating polygon for node 36946270: If using all scalar values, you must pass an index
# Processing node 63/4953: 36946270
# Error creating polygon for node 36946270: If using all scalar values, you must pass an index
# Processing node 64/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 65/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 66/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 67/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 68/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 69/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 70/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 71/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 72/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 73/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 74/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 75/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 76/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 77/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 78/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 79/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 80/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 81/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 82/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 83/4953: 36975848
# Error creating polygon for node 36975848: If using all scalar values, you must pass an index
# Processing node 84/4953: 5090486949
# Error creating polygon for node 5090486949: If using all scalar values, you must pass an index
# Processing node 85/4953: 5090486949
# Error creating polygon for node 5090486949: If using all scalar values, you must pass an index
# Processing node 86/4953: 5090486949
# Error creating polygon for node 5090486949: If using all scalar values, you must pass an index
# Processing node 87/4953: 5090486949
# Error creating polygon for node 5090486949: If using all scalar values, you must pass an index
# Processing node 88/4953: 5090486949
# Error creating polygon for node 5090486949: If using all scalar values, you must pass an index
# Processing node 89/4953: 5090486949
# Error creating polygon for node 5090486949: If using all scalar values, you must pass an index
# Processing node 90/4953: 36915047
# Error creating polygon for node 36915047: If using all scalar values, you must pass an index
# Processing node 91/4953: 36937266
# Error creating polygon for node 36937266: If using all scalar values, you must pass an index
# Processing node 92/4953: 36937266
# Error creating polygon for node 36937266: If using all scalar values, you must pass an index
# Processing node 93/4953: 36937266
# Error creating polygon for node 36937266: If using all scalar values, you must pass an index
# Processing node 94/4953: 36937266
# Error creating polygon for node 36937266: If using all scalar values, you must pass an index
# Processing node 95/4953: 36937266
# Error creating polygon for node 36937266: If using all scalar values, you must pass an index
# Processing node 96/4953: 36937266
# Error creating polygon for node 36937266: If using all scalar values, you must pass an index
# Processing node 97/4953: 2377109034
# Error creating polygon for node 2377109034: If using all scalar values, you must pass an index
# Processing node 98/4953: 2377109034
# Error creating polygon for node 2377109034: If using all scalar values, you must pass an index
# Processing node 99/4953: 2377109034
# Error creating polygon for node 2377109034: If using all scalar values, you must pass an index
# Processing node 100/4953: 36937276
# Error creating polygon for node 36937276: If using all scalar values, you must pass an index
# Processing node 101/4953: 36937276
# Error creating polygon for node 36937276: If using all scalar values, you must pass an index
# Processing node 102/4953: 36937276
# Error creating polygon for node 36937276: If using all scalar values, you must pass an index
# Processing node 103/4953: 36965514
# Error creating polygon for node 36965514: If using all scalar values, you must pass an index
# Processing node 104/4953: 36965514
# Error creating polygon for node 36965514: If using all scalar values, you must pass an index
# Processing node 105/4953: 36960539
# Error creating polygon for node 36960539: If using all scalar values, you must pass an index
# Processing node 106/4953: 36960547
# Error creating polygon for node 36960547: If using all scalar values, you must pass an index
# Processing node 107/4953: 36930450
# Error creating polygon for node 36930450: If using all scalar values, you must pass an index
# Processing node 108/4953: 1187335418
# Error creating polygon for node 1187335418: If using all scalar values, you must pass an index
# Processing node 109/4953: 36973869
# Error creating polygon for node 36973869: If using all scalar values, you must pass an index
# Processing node 110/4953: 36973869
# Error creating polygon for node 36973869: If using all scalar values, you must pass an index
# Processing node 111/4953: 36973869
# Error creating polygon for node 36973869: If using all scalar values, you must pass an index
# Processing node 112/4953: 36973869
# Error creating polygon for node 36973869: If using all scalar values, you must pass an index
# Processing node 113/4953: 36973869
# Error creating polygon for node 36973869: If using all scalar values, you must pass an index
# Processing node 114/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 115/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 116/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 117/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 118/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 119/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 120/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 121/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 122/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 123/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 124/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 125/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 126/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 127/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 128/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 129/4953: 36914995
# Error creating polygon for node 36914995: If using all scalar values, you must pass an index
# Processing node 130/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 131/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 132/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 133/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 134/4953: 36973862
# Error creating polygon for node 36973862: If using all scalar values, you must pass an index
# Processing node 135/4953: 36973862
# Error creating polygon for node 36973862: If using all scalar values, you must pass an index
# Processing node 136/4953: 36973862
# Error creating polygon for node 36973862: If using all scalar values, you must pass an index
# Processing node 137/4953: 36973862
# Error creating polygon for node 36973862: If using all scalar values, you must pass an index
# Processing node 138/4953: 36973862
# Error creating polygon for node 36973862: If using all scalar values, you must pass an index
# Processing node 139/4953: 36973862
# Error creating polygon for node 36973862: If using all scalar values, you must pass an index
# Processing node 140/4953: 36973862
# Error creating polygon for node 36973862: If using all scalar values, you must pass an index
# Processing node 141/4953: 36973862
# Error creating polygon for node 36973862: If using all scalar values, you must pass an index
# Processing node 142/4953: 6453567582
# Not enough points (1) to create polygon for node 6453567582
# Processing node 143/4953: 36935476
# Error creating polygon for node 36935476: If using all scalar values, you must pass an index
# Processing node 144/4953: 6453567582
# Not enough points (1) to create polygon for node 6453567582
# Processing node 145/4953: 6453567582
# Not enough points (1) to create polygon for node 6453567582
# Processing node 146/4953: 36914996
# Error creating polygon for node 36914996: If using all scalar values, you must pass an index
# Processing node 147/4953: 36959359
# Error creating polygon for node 36959359: If using all scalar values, you must pass an index
# Processing node 148/4953: 36959359
# Error creating polygon for node 36959359: If using all scalar values, you must pass an index
# Processing node 149/4953: 36944051
# Error creating polygon for node 36944051: If using all scalar values, you must pass an index
# Processing node 150/4953: 36959359
# Error creating polygon for node 36959359: If using all scalar values, you must pass an index
# Processing node 151/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 152/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 153/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 154/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 155/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 156/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 157/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 158/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 159/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 160/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 161/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 162/4953: 36913163
# Error creating polygon for node 36913163: If using all scalar values, you must pass an index
# Processing node 163/4953: 36913163
# Error creating polygon for node 36913163: If using all scalar values, you must pass an index
# Processing node 164/4953: 36959356
# Error creating polygon for node 36959356: If using all scalar values, you must pass an index
# Processing node 165/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 166/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 167/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 168/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 169/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 170/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 171/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 172/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 173/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 174/4953: 36987238
# Error creating polygon for node 36987238: If using all scalar values, you must pass an index
# Processing node 175/4953: 36913163
# Error creating polygon for node 36913163: If using all scalar values, you must pass an index
# Processing node 176/4953: 36913163
# Error creating polygon for node 36913163: If using all scalar values, you must pass an index
# Processing node 177/4953: 36913163
# Error creating polygon for node 36913163: If using all scalar values, you must pass an index
# Processing node 178/4953: 36913163
# Error creating polygon for node 36913163: If using all scalar values, you must pass an index
# Processing node 179/4953: 36913163
# Error creating polygon for node 36913163: If using all scalar values, you must pass an index
# Processing node 180/4953: 36913163
# Error creating polygon for node 36913163: If using all scalar values, you must pass an index
# Processing node 181/4953: 5087803199
# Error creating polygon for node 5087803199: If using all scalar values, you must pass an index
# Processing node 182/4953: 5087803199
# Error creating polygon for node 5087803199: If using all scalar values, you must pass an index
# Processing node 183/4953: 5087803199
# Error creating polygon for node 5087803199: If using all scalar values, you must pass an index
# Processing node 184/4953: 5087803199
# Error creating polygon for node 5087803199: If using all scalar values, you must pass an index
# Processing node 185/4953: 5087803199
# Error creating polygon for node 5087803199: If using all scalar values, you must pass an index
# Processing node 186/4953: 36935476
# Error creating polygon for node 36935476: If using all scalar values, you must pass an index
# Processing node 187/4953: 36935476
# Error creating polygon for node 36935476: If using all scalar values, you must pass an index
# Processing node 188/4953: 36935476
# Error creating polygon for node 36935476: If using all scalar values, you must pass an index
# Processing node 189/4953: 36935476
# Error creating polygon for node 36935476: If using all scalar values, you must pass an index
# Processing node 190/4953: 36935476
# Error creating polygon for node 36935476: If using all scalar values, you must pass an index
# Processing node 191/4953: 36935476
# Error creating polygon for node 36935476: If using all scalar values, you must pass an index
# Processing node 192/4953: 36959362
# Error creating polygon for node 36959362: If using all scalar values, you must pass an index
# Processing node 193/4953: 36913157
# Error creating polygon for node 36913157: If using all scalar values, you must pass an index
# Processing node 194/4953: 36913157
# Error creating polygon for node 36913157: If using all scalar values, you must pass an index
# Processing node 195/4953: 36913157
# Error creating polygon for node 36913157: If using all scalar values, you must pass an index
# Processing node 196/4953: 36913157
# Error creating polygon for node 36913157: If using all scalar values, you must pass an index
# Processing node 197/4953: 36913157
# Error creating polygon for node 36913157: If using all scalar values, you must pass an index
# Processing node 198/4953: 36913157
# Error creating polygon for node 36913157: If using all scalar values, you must pass an index
# Processing node 199/4953: 36913157
# Error creating polygon for node 36913157: If using all scalar values, you must pass an index
# Processing node 200/4953: 36914995
# Error creating polygon for node 36914995: If using all scalar values, you must pass an index
# Processing node 201/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 202/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 203/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 204/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 205/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 206/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 207/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 208/4953: 36970813
# Error creating polygon for node 36970813: If using all scalar values, you must pass an index
# Processing node 209/4953: 36959366
# Error creating polygon for node 36959366: If using all scalar values, you must pass an index
# Processing node 210/4953: 5087803199
# Error creating polygon for node 5087803199: If using all scalar values, you must pass an index
# Processing node 211/4953: 5087803199
# Error creating polygon for node 5087803199: If using all scalar values, you must pass an index
# Processing node 212/4953: 5087803199
# Error creating polygon for node 5087803199: If using all scalar values, you must pass an index
# Processing node 213/4953: 36973869
# Error creating polygon for node 36973869: If using all scalar values, you must pass an index
# Processing node 214/4953: 36973869
# Error creating polygon for node 36973869: If using all scalar values, you must pass an index
# Processing node 215/4953: 36973869
# Error creating polygon for node 36973869: If using all scalar values, you must pass an index
# Processing node 216/4953: 36973869
# Error creating polygon for node 36973869: If using all scalar values, you must pass an index
# Processing node 217/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 218/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 219/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 220/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 221/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 222/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 223/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 224/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 225/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 226/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 227/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 228/4953: 5087803209
# Error creating polygon for node 5087803209: If using all scalar values, you must pass an index
# Processing node 229/4953: 36944051
# Error creating polygon for node 36944051: If using all scalar values, you must pass an index
# Processing node 230/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 231/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 232/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 233/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 234/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 235/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 236/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 237/4953: 5087803202
# Error creating polygon for node 5087803202: If using all scalar values, you must pass an index
# Processing node 238/4953: 36914993
# Error creating polygon for node 36914993: If using all scalar values, you must pass an index
# Processing node 239/4953: 36913170
# Error creating polygon for node 36913170: If using all scalar values, you must pass an index
# Processing node 240/4953: 36913170
# Error creating polygon for node 36913170: If using all scalar values, you must pass an index
# Processing node 241/4953: 36913170
# Error creating polygon for node 36913170: If using all scalar values, you must pass an index
# Processing node 242/4953: 36913170
# Error creating polygon for node 36913170: If using all scalar values, you must pass an index
# Processing node 243/4953: 36973869
# Error creating polygon for node 36973869: If using all scalar values, you must pass an index
# Processing node 244/4953: 36973869
# Error creating polygon for node 36973869: If using all scalar values, you must pass an index
# Processing node 245/4953: 36973869
# Error creating polygon for node 36973869: If using all scalar values, you must pass an index
# Processing node 246/4953: 36973869
# Error creating polygon for node 36973869: If using all scalar values, you must pass an index
# Processing node 247/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 248/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 249/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 250/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 251/4953: 36913157
# Error creating polygon for node 36913157: If using all scalar values, you must pass an index
# Processing node 252/4953: 36913157
# Error creating polygon for node 36913157: If using all scalar values, you must pass an index
# Processing node 253/4953: 36913157
# Error creating polygon for node 36913157: If using all scalar values, you must pass an index
# Processing node 254/4953: 36913157
# Error creating polygon for node 36913157: If using all scalar values, you must pass an index
# Processing node 255/4953: 36922161
# Error creating polygon for node 36922161: If using all scalar values, you must pass an index
# Processing node 256/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 257/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 258/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 259/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 260/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 261/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 262/4953: 10110197583
# Error creating polygon for node 10110197583: If using all scalar values, you must pass an index
# Processing node 263/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 264/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 265/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 266/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 267/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 268/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 269/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 270/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 271/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 272/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 273/4953: 36913163
# Error creating polygon for node 36913163: If using all scalar values, you must pass an index
# Processing node 274/4953: 36913163
# Error creating polygon for node 36913163: If using all scalar values, you must pass an index
# Processing node 275/4953: 36913163
# Error creating polygon for node 36913163: If using all scalar values, you must pass an index
# Processing node 276/4953: 36913163
# Error creating polygon for node 36913163: If using all scalar values, you must pass an index
# Processing node 277/4953: 36944051
# Error creating polygon for node 36944051: If using all scalar values, you must pass an index
# Processing node 278/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 279/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 280/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 281/4953: 36913146
# Error creating polygon for node 36913146: If using all scalar values, you must pass an index
# Processing node 282/4953: 36913146
# Error creating polygon for node 36913146: If using all scalar values, you must pass an index
# Processing node 283/4953: 36913146
# Error creating polygon for node 36913146: If using all scalar values, you must pass an index
# Processing node 284/4953: 36913146
# Error creating polygon for node 36913146: If using all scalar values, you must pass an index
# Processing node 285/4953: 36984863
# Error creating polygon for node 36984863: If using all scalar values, you must pass an index
# Processing node 286/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 287/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 288/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 289/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 290/4953: 36915042
# Error creating polygon for node 36915042: If using all scalar values, you must pass an index
# Processing node 291/4953: 36959356
# Error creating polygon for node 36959356: If using all scalar values, you must pass an index
# Processing node 292/4953: 36987238
# Error creating polygon for node 36987238: If using all scalar values, you must pass an index
# Processing node 293/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 294/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 295/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 296/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 297/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 298/4953: 36959366
# Error creating polygon for node 36959366: If using all scalar values, you must pass an index
# Processing node 299/4953: 5087803192
# Error creating polygon for node 5087803192: If using all scalar values, you must pass an index
# Processing node 300/4953: 36959359
# Error creating polygon for node 36959359: If using all scalar values, you must pass an index
# Processing node 301/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 302/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 303/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 304/4953: 36959366
# Error creating polygon for node 36959366: If using all scalar values, you must pass an index
# Processing node 305/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 306/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 307/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 308/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 309/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 310/4953: 36944051
# Error creating polygon for node 36944051: If using all scalar values, you must pass an index
# Processing node 311/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 312/4953: 36913152
# Error creating polygon for node 36913152: If using all scalar values, you must pass an index
# Processing node 313/4953: 36935476
# Error creating polygon for node 36935476: If using all scalar values, you must pass an index
# Processing node 314/4953: 36935476
# Error creating polygon for node 36935476: If using all scalar values, you must pass an index
# Processing node 315/4953: 36935476
# Error creating polygon for node 36935476: If using all scalar values, you must pass an index
# Processing node 316/4953: 36935476
# Error creating polygon for node 36935476: If using all scalar values, you must pass an index
# Processing node 317/4953: 36935476
# Error creating polygon for node 36935476: If using all scalar values, you must pass an index
# Processing node 318/4953: 36935476
# Error creating polygon for node 36935476: If using all scalar values, you must pass an index
# Processing node 319/4953: 36959366
# Error creating polygon for node 36959366: If using all scalar values, you must pass an index
# Processing node 320/4953: 36984863
# Error creating polygon for node 36984863: If using all scalar values, you must pass an index
# Processing node 321/4953: 36913157
# Error creating polygon for node 36913157: If using all scalar values, you must pass an index
# Processing node 322/4953: 36913157
# Error creating polygon for node 36913157: If using all scalar values, you must pass an index
# Processing node 323/4953: 36913157
# Error creating polygon for node 36913157: If using all scalar values, you must pass an index
# Processing node 324/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 325/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 326/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 327/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 328/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 329/4953: 36943490
# Error creating polygon for node 36943490: If using all scalar values, you must pass an index
# Processing node 330/4953: 36913146
# Error creating polygon for node 36913146: If using all scalar values, you must pass an index
# Processing node 331/4953: 36913146
# Error creating polygon for node 36913146: If using all scalar values, you must pass an index
# Processing node 332/4953: 36913146
# Error creating polygon for node 36913146: If using all scalar values, you must pass an index
# Processing node 333/4953: 36913146
# Error creating polygon for node 36913146: If using all scalar values, you must pass an index
# Processing node 334/4953: 36913146
# Error creating polygon for node 36913146: If using all scalar values, you must pass an index
# Processing node 335/4953: 36913146
# Error creating polygon for node 36913146: If using all scalar values, you must pass an index
# Processing node 336/4953: 36913146
# Error creating polygon for node 36913146: If using all scalar values, you must pass an index
# Processing node 337/4953: 36915044
# Error creating polygon for node 36915044: If using all scalar values, you must pass an index
# Processing node 338/4953: 36915044
# Error creating polygon for node 36915044: If using all scalar values, you must pass an index
# Processing node 339/4953: 36915044
# Error creating polygon for node 36915044: If using all scalar values, you must pass an index
# Processing node 340/4953: 36915044
# Error creating polygon for node 36915044: If using all scalar values, you must pass an index
# Processing node 341/4953: 36915044
# Error creating polygon for node 36915044: If using all scalar values, you must pass an index
# Processing node 342/4953: 36915044
# Error creating polygon for node 36915044: If using all scalar values, you must pass an index
# Processing node 343/4953: 36959366
# Error creating polygon for node 36959366: If using all scalar values, you must pass an index
# Processing node 344/4953: 5087803201
# Error creating polygon for node 5087803201: If using all scalar values, you must pass an index
# Processing node 345/4953: 5087803202
# Error creating polygon for node 5087803202: If using all scalar values, you must pass an index
# Processing node 346/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 347/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 348/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 349/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 350/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 351/4953: 36973869
# Error creating polygon for node 36973869: If using all scalar values, you must pass an index
# Processing node 352/4953: 36973869
# Error creating polygon for node 36973869: If using all scalar values, you must pass an index
# Processing node 353/4953: 36973869
# Error creating polygon for node 36973869: If using all scalar values, you must pass an index
# Processing node 354/4953: 36973869
# Error creating polygon for node 36973869: If using all scalar values, you must pass an index
# Processing node 355/4953: 36973869
# Error creating polygon for node 36973869: If using all scalar values, you must pass an index
# Processing node 356/4953: 36913141
# Error creating polygon for node 36913141: If using all scalar values, you must pass an index
# Processing node 357/4953: 36913163
# Error creating polygon for node 36913163: If using all scalar values, you must pass an index
# Processing node 358/4953: 36913163
# Error creating polygon for node 36913163: If using all scalar values, you must pass an index
# Processing node 359/4953: 36913163
# Error creating polygon for node 36913163: If using all scalar values, you must pass an index
# Processing node 360/4953: 36935476
# Error creating polygon for node 36935476: If using all scalar values, you must pass an index
# Processing node 361/4953: 36935476
# Error creating polygon for node 36935476: If using all scalar values, you must pass an index
# Processing node 362/4953: 36935476
# Error creating polygon for node 36935476: If using all scalar values, you must pass an index
# Processing node 363/4953: 36935476
# Error creating polygon for node 36935476: If using all scalar values, you must pass an index
# Processing node 364/4953: 36935476
# Error creating polygon for node 36935476: If using all scalar values, you must pass an index
# Processing node 365/4953: 36944050
# Error creating polygon for node 36944050: If using all scalar values, you must pass an index
# Processing node 366/4953: 5087803199
# Error creating polygon for node 5087803199: If using all scalar values, you must pass an index
# Processing node 367/4953: 5087803199
# Error creating polygon for node 5087803199: If using all scalar values, you must pass an index
# Processing node 368/4953: 5087803199
# Error creating polygon for node 5087803199: If using all scalar values, you must pass an index
# Processing node 369/4953: 5087803199
# Error creating polygon for node 5087803199: If using all scalar values, you must pass an index
# Processing node 370/4953: 36959362
# Error creating polygon for node 36959362: If using all scalar values, you must pass an index
# Processing node 371/4953: 36913170
# Error creating polygon for node 36913170: If using all scalar values, you must pass an index
# Processing node 372/4953: 36913170
# Error creating polygon for node 36913170: If using all scalar values, you must pass an index
# Processing node 373/4953: 36913170
# Error creating polygon for node 36913170: If using all scalar values, you must pass an index
# Processing node 374/4953: 36913170
# Error creating polygon for node 36913170: If using all scalar values, you must pass an index
# Processing node 375/4953: 36913170
# ...
# Processing node 4831/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4832/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4833/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4834/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4835/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4836/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4837/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4838/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4839/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4840/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4841/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4842/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4843/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4844/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4845/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4846/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4847/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4848/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4849/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4850/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4851/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4852/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4853/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4854/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4855/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 4856/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4857/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4858/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4859/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4860/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4861/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4862/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4863/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4864/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 4865/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4866/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4867/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4868/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4869/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4870/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4871/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4872/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4873/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4874/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 4875/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 4876/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4877/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4878/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4879/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4880/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4881/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4882/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4883/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4884/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4885/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4886/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4887/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4888/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4889/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 4890/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4891/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4892/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4893/4953: 36981877
# Error creating polygon for node 36981877: If using all scalar values, you must pass an index
# Processing node 4894/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4895/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4896/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4897/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4898/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4899/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4900/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4901/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4902/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4903/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4904/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4905/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4906/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4907/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4908/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4909/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4910/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4911/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4912/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4913/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4914/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4915/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4916/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4917/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4918/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4919/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4920/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4921/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4922/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4923/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4924/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4925/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4926/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4927/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4928/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4929/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4930/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4931/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4932/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4933/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4934/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4935/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4936/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4937/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4938/4953: 36915040
# Error creating polygon for node 36915040: If using all scalar values, you must pass an index
# Processing node 4939/4953: 36943482
# Error creating polygon for node 36943482: If using all scalar values, you must pass an index
# Processing node 4940/4953: 36985247
# Error creating polygon for node 36985247: If using all scalar values, you must pass an index
# Processing node 4941/4953: 36985247
# Error creating polygon for node 36985247: If using all scalar values, you must pass an index
# Processing node 4942/4953: 36985247
# Error creating polygon for node 36985247: If using all scalar values, you must pass an index
# Processing node 4943/4953: 36985247
# Error creating polygon for node 36985247: If using all scalar values, you must pass an index
# Processing node 4944/4953: 36985247
# Error creating polygon for node 36985247: If using all scalar values, you must pass an index
# Processing node 4945/4953: 36985247
# Error creating polygon for node 36985247: If using all scalar values, you must pass an index
# Processing node 4946/4953: 36985247
# Error creating polygon for node 36985247: If using all scalar values, you must pass an index
# Processing node 4947/4953: 36985247
# Error creating polygon for node 36985247: If using all scalar values, you must pass an index
# Processing node 4948/4953: 36985247
# Error creating polygon for node 36985247: If using all scalar values, you must pass an index
# Processing node 4949/4953: 12558425730
# Error creating polygon for node 12558425730: If using all scalar values, you must pass an index
# Processing node 4950/4953: 12558425723
# Error creating polygon for node 12558425723: If using all scalar values, you must pass an index
# Processing node 4951/4953: 3007746547
# Error creating polygon for node 3007746547: If using all scalar values, you must pass an index
# Processing node 4952/4953: 36914951
# Error creating polygon for node 36914951: If using all scalar values, you must pass an index
# Processing node 4953/4953: 12558425730
# Error creating polygon for node 12558425730: If using all scalar values, you must pass an index
# No isochrones were created successfully.

# %%
import networkx as nx
import geopandas as gpd
import os
import numpy as np
from shapely.geometry import Polygon, Point
from scipy.spatial import ConvexHull
import pandas as pd

# 1. Load the GraphML file (still using osmnx just for loading)
downloads_path = os.path.join(os.path.expanduser("~"), "Downloads")
graph = nx.read_graphml(os.path.join(downloads_path, "oregon_drive_network_projected.graphml"))

# Extract CRS from the graph attributes (assuming it's stored there)
graph_crs = None
if 'crs' in graph.graph:
    graph_crs = graph.graph['crs']
else:
    # Default to a common projection for Oregon (UTM Zone 10N)
    graph_crs = "EPSG:32610"
    print(f"No CRS found in graph, using default: {graph_crs}")

# 2. Load Point Data
basefolder = "C:/Users/weckero/Documents/Tobackup/"
points_gdf = gpd.read_file(basefolder + "people_points.shp")
if graph_crs:
    points_gdf = points_gdf.to_crs(graph_crs)

# 3. Add travel time to edges if not present
print("Checking and adding travel time to edges...")
need_travel_time = False

# Check a sample edge
sample_edge = list(graph.edges(data=True))[0][2]
if 'travel_time' not in sample_edge:
    need_travel_time = True

if need_travel_time:
    # Add travel time based on length and speed (if available)
    for u, v, data in graph.edges(data=True):
        if 'length' in data and 'speed_kph' in data:
            # Convert km/h to m/s and calculate travel time
            speed_ms = float(data['speed_kph']) * 1000 / 3600
            data['travel_time'] = float(data['length']) / speed_ms
        else:
            # Default travel time of 3 minutes if we don't have speed/length
            data['travel_time'] = 180  # 3 minutes in seconds
    print("Added travel_time attribute to edges")

# 4. Find nearest nodes for each point
nearest_nodes = []
for idx, point in points_gdf.iterrows():
    # Get point coordinates
    point_x, point_y = point.geometry.x, point.geometry.y
    
    # Find the nearest node in the graph
    min_dist = float('inf')
    nearest = None
    
    for node, data in graph.nodes(data=True):
        # Skip nodes without coordinates
        if 'x' not in data or 'y' not in data:
            continue
            
        # Calculate Euclidean distance
        node_x, node_y = float(data['x']), float(data['y'])  # Convert to float to be safe
        dist = ((node_x - point_x) ** 2 + (node_y - point_y) ** 2) ** 0.5
        
        if dist < min_dist:
            nearest = node
            min_dist = dist
    
    if nearest:
        nearest_nodes.append(nearest)
        print(f"Found nearest node {nearest} for point {idx+1}/{len(points_gdf)}")
    else:
        print(f"WARNING: No nearest node found for point {idx+1}")
        nearest_nodes.append(None)  # Placeholder

# 5. Generate Isochrones
travel_time = 3600  # 1 hour in seconds
isochrones_list = []

for i, node in enumerate(nearest_nodes):
    if node is None:
        print(f"Skipping point {i+1} - no valid node found")
        continue
        
    print(f"Processing node {i+1}/{len(nearest_nodes)}: {node}")
    
    try:
        # Get all nodes reachable within travel_time using NetworkX
        lengths = nx.single_source_dijkstra_path_length(
            G=graph, 
            source=node, 
            cutoff=travel_time, 
            weight='travel_time'
        )
        
        reachable_nodes = list(lengths.keys())
        
        if not reachable_nodes:
            print(f"No nodes within travel time for node {node}")
            continue
            
        # Get coordinates for reachable nodes
        node_points = []
        for n in reachable_nodes:
            try:
                # Cast to float to avoid any string conversion issues
                node_points.append((float(graph.nodes[n]['x']), float(graph.nodes[n]['y'])))
            except (KeyError, ValueError):
                # Skip nodes without valid coordinates
                continue
        
        if len(node_points) < 3:
            print(f"Not enough points ({len(node_points)}) to create polygon for node {node}")
            continue
            
        # Create a convex hull for the isochrone
        try:
            hull = ConvexHull(node_points)
            polygon_points = [node_points[i] for i in hull.vertices]
            
            # Create Polygon
            isochrone_polygon = Polygon(polygon_points)
            
            # If the polygon is valid, add it to our results
            if isochrone_polygon.is_valid:
                # Copy attributes from the original point
                point_info = {}
                if i < len(points_gdf):
                    for col in points_gdf.columns:
                        if col != 'geometry':
                            val = points_gdf.iloc[i][col]
                            # Convert numpy types to Python types for shapefile compatibility
                            if isinstance(val, (np.integer, np.floating, np.bool_)):
                                val = val.item()
                            point_info[col] = val
                
                isochrone_gdf = gpd.GeoDataFrame(
                    {**point_info, 'node_id': str(node), 'travel_mins': float(travel_time/60)},
                    geometry=[isochrone_polygon], 
                    crs=graph_crs
                )
                
                isochrones_list.append(isochrone_gdf)
                print(f"Successfully created isochrone for node {node}")
            else:
                print(f"Created invalid polygon for node {node}")
            
        except Exception as e:
            print(f"Error creating polygon for node {node}: {e}")
                
    except Exception as e:
        print(f"Error calculating paths for node {node}: {e}")

# 6. Combine all isochrones into a single GeoDataFrame
if isochrones_list:
    try:
        isochrones_gdf = pd.concat(isochrones_list)
        
        # Save the isochrones
        isochrones_output = os.path.join(basefolder, "isochrones_points.shp")
        isochrones_gdf.to_file(isochrones_output)
        print(f"Saved {len(isochrones_list)} isochrones to {isochrones_output}")
    except Exception as e:
        print(f"Error combining/saving isochrones: {e}")
        # Try to save individually
        for i, iso_gdf in enumerate(isochrones_list):
            try:
                iso_output = os.path.join(basefolder, f"isochrone_{i}.shp")
                iso_gdf.to_file(iso_output)
                print(f"Saved individual isochrone to {iso_output}")
            except Exception as e2:
                print(f"Could not save isochrone {i}: {e2}")
else:
    print("No isochrones were created successfully.")
# Out:
# Checking and adding travel time to edges...
# Added travel_time attribute to edges
# Found nearest node 36944611 for point 1/4953
# Found nearest node 12177744664 for point 2/4953
# Found nearest node 4854467950 for point 3/4953
# Found nearest node 7058457949 for point 4/4953
# Found nearest node 7058457949 for point 5/4953
# Found nearest node 7058457949 for point 6/4953
# Found nearest node 4854467950 for point 7/4953
# Found nearest node 36959155 for point 8/4953
# Found nearest node 36959155 for point 9/4953
# Found nearest node 36959155 for point 10/4953
# Found nearest node 36959155 for point 11/4953
# Found nearest node 36959155 for point 12/4953
# Found nearest node 36959155 for point 13/4953
# Found nearest node 36921184 for point 14/4953
# Found nearest node 10181880066 for point 15/4953
# Found nearest node 10181880066 for point 16/4953
# Found nearest node 36936470 for point 17/4953
# Found nearest node 36936470 for point 18/4953
# Found nearest node 36936470 for point 19/4953
# Found nearest node 36936470 for point 20/4953
# Found nearest node 36936470 for point 21/4953
# Found nearest node 36936470 for point 22/4953
# Found nearest node 36936470 for point 23/4953
# Found nearest node 11918887669 for point 24/4953
# Found nearest node 11918887669 for point 25/4953
# Found nearest node 11918887669 for point 26/4953
# Found nearest node 11918887669 for point 27/4953
# Found nearest node 11918887669 for point 28/4953
# Found nearest node 11918887669 for point 29/4953
# Found nearest node 11918887669 for point 30/4953
# Found nearest node 11918887669 for point 31/4953
# Found nearest node 36934606 for point 32/4953
# Found nearest node 36987804 for point 33/4953
# Found nearest node 36944611 for point 34/4953
# Found nearest node 36944611 for point 35/4953
# Found nearest node 36944611 for point 36/4953
# Found nearest node 36944611 for point 37/4953
# Found nearest node 36981870 for point 38/4953
# Found nearest node 4854467950 for point 39/4953
# Found nearest node 36935380 for point 40/4953
# Found nearest node 36934576 for point 41/4953
# Found nearest node 36936458 for point 42/4953
# Found nearest node 36936458 for point 43/4953
# Found nearest node 36921173 for point 44/4953
# Found nearest node 36921173 for point 45/4953
# Found nearest node 36921173 for point 46/4953
# Found nearest node 36921173 for point 47/4953
# Found nearest node 36921173 for point 48/4953
# Processing node 4952/4953: 36914951
# Error creating polygon for node 36914951: If using all scalar values, you must pass an index
# Processing node 4953/4953: 12558425730
# Error creating polygon for node 12558425730: If using all scalar values, you must pass an index
# No isochrones were created successfully.

# %%
import networkx as nx
import geopandas as gpd
import os
import numpy as np
from shapely.geometry import Polygon, Point
from scipy.spatial import ConvexHull
import pandas as pd

# 1. Load the GraphML file (using networkx directly)
downloads_path = os.path.join(os.path.expanduser("~"), "Downloads")
graph = nx.read_graphml(os.path.join(downloads_path, "oregon_drive_network_projected.graphml"))

# Extract CRS from the graph attributes
graph_crs = None
if 'crs' in graph.graph:
    graph_crs = graph.graph['crs']
else:
    # Default to a common projection for Oregon (UTM Zone 10N)
    graph_crs = "EPSG:32610"
    print(f"No CRS found in graph, using default: {graph_crs}")

# 2. Load Point Data
documents_path = os.path.join(os.path.expanduser("~"), "Documents")
basefolder = "C:/Users/weckero/Documents/"
points_gdf = gpd.read_file(basefolder + "clipped_tester.shp")
if graph_crs:
    points_gdf = points_gdf.to_crs(graph_crs)

# 3. Add travel time to edges if not present
print("Checking and adding travel time to edges...")
need_travel_time = False

# Check a sample edge
sample_edge = list(graph.edges(data=True))[0][2]
if 'travel_time' not in sample_edge:
    need_travel_time = True

if need_travel_time:
    # Add travel time based on length and speed (if available)
    for u, v, data in graph.edges(data=True):
        if 'length' in data and 'speed_kph' in data:
            # Convert km/h to m/s and calculate travel time
            speed_ms = float(data['speed_kph']) * 1000 / 3600
            data['travel_time'] = float(data['length']) / speed_ms
        else:
            # Default travel time of 3 minutes if we don't have speed/length
            data['travel_time'] = 600  # 10 minutes in seconds
    print("Added travel_time attribute to edges: default 10 minutes")

# 4. Find nearest nodes for each point
nearest_nodes = []
for idx, point in points_gdf.iterrows():
    # Get point coordinates
    point_x, point_y = point.geometry.x, point.geometry.y
    
    # Find the nearest node in the graph
    min_dist = float('inf')
    nearest = None
    
    for node, data in graph.nodes(data=True):
        # Skip nodes without coordinates
        if 'x' not in data or 'y' not in data:
            continue
            
        # Calculate Euclidean distance
        node_x, node_y = float(data['x']), float(data['y'])
        dist = ((node_x - point_x) ** 2 + (node_y - point_y) ** 2) ** 0.5
        
        if dist < min_dist:
            nearest = node
            min_dist = dist
    
    if nearest:
        nearest_nodes.append(nearest)
        print(f"Found nearest node {nearest} for point {idx+1}/{len(points_gdf)}")
    else:
        print(f"WARNING: No nearest node found for point {idx+1}")
        nearest_nodes.append(None)  # Placeholder

# 5. Generate Isochrones
travel_time = 600 #10 minutes
isochrones_list = []

for i, node in enumerate(nearest_nodes):
    if node is None:
        print(f"Skipping point {i+1} - no valid node found")
        continue
        
    print(f"Processing node {i+1}/{len(nearest_nodes)}: {node}")
    
    try:
        # Get all nodes reachable within travel_time using NetworkX
        lengths = nx.single_source_dijkstra_path_length(
            G=graph, 
            source=node, 
            cutoff=travel_time, 
            weight='travel_time'
        )
        
        reachable_nodes = list(lengths.keys())
        
        if not reachable_nodes:
            print(f"No nodes within travel time for node {node}")
            continue
            
        # Get coordinates for reachable nodes
        node_points = []
        for n in reachable_nodes:
            try:
                node_points.append((float(graph.nodes[n]['x']), float(graph.nodes[n]['y'])))
            except (KeyError, ValueError):
                # Skip nodes without valid coordinates
                continue
        
        if len(node_points) < 3:
            print(f"Not enough points ({len(node_points)}) to create polygon for node {node}")
            continue
            
        # Create a convex hull for the isochrone
        try:
            hull = ConvexHull(node_points)
            polygon_points = [node_points[i] for i in hull.vertices]
            
            # Create Polygon
            isochrone_polygon = Polygon(polygon_points)
            
            # If the polygon is valid, add it to our results
            if isochrone_polygon.is_valid:
                # Create a dictionary for the data row
                row_data = {'geometry': isochrone_polygon, 'node_id': str(node), 'travel_mins': float(travel_time/60)}
                
                # Add point attributes
                if i < len(points_gdf):
                    for col in points_gdf.columns:
                        if col != 'geometry':
                            val = points_gdf.iloc[i][col]
                            # Convert numpy types to Python types
                            if isinstance(val, (np.integer, np.floating, np.bool_)):
                                val = val.item()
                            row_data[col] = val
                
                # Create a DataFrame with a single row and convert to GeoDataFrame
                row_df = pd.DataFrame([row_data])
                isochrone_gdf = gpd.GeoDataFrame(
                    row_df, 
                    geometry='geometry',
                    crs=graph_crs
                )
                
                isochrones_list.append(isochrone_gdf)
                print(f"Successfully created isochrone for node {node}")
            else:
                print(f"Created invalid polygon for node {node}")
            
        except Exception as e:
            print(f"Error creating polygon for node {node}: {e}")
                
    except Exception as e:
        print(f"Error calculating paths for node {node}: {e}")

# 6. Combine all isochrones into a single GeoDataFrame
if isochrones_list:
    try:
        isochrones_gdf = pd.concat(isochrones_list)
        
        # Save the isochrones
        isochrones_output = os.path.join(basefolder, "isochrones_points.shp")
        isochrones_gdf.to_file(isochrones_output)
        print(f"Saved {len(isochrones_list)} isochrones to {isochrones_output}")
    except Exception as e:
        print(f"Error combining/saving isochrones: {e}")
        # Try to save individually
        for i, iso_gdf in enumerate(isochrones_list):
            try:
                iso_output = os.path.join(basefolder, f"isochrone_{i}.shp")
                iso_gdf.to_file(iso_output)
                print(f"Saved individual isochrone to {iso_output}")
            except Exception as e2:
                print(f"Could not save isochrone {i}: {e2}")
else:
    print("No isochrones were created successfully.")
# Out:
# Checking and adding travel time to edges...
# Added travel_time attribute to edges: default 10 minutes
# Found nearest node 36960892 for point 1/110
# Found nearest node 36960892 for point 2/110
# Found nearest node 36982363 for point 3/110
# Found nearest node 36982363 for point 4/110
# Found nearest node 36982363 for point 5/110
# Found nearest node 36960892 for point 6/110
# Found nearest node 36960892 for point 7/110
# Found nearest node 36960892 for point 8/110
# Found nearest node 36960892 for point 9/110
# Found nearest node 36960892 for point 10/110
# Found nearest node 36960892 for point 11/110
# Found nearest node 36960892 for point 12/110
# Found nearest node 36960897 for point 13/110
# Found nearest node 36960897 for point 14/110
# Found nearest node 36926678 for point 15/110
# Found nearest node 36956706 for point 16/110
# Found nearest node 36926678 for point 17/110
# Found nearest node 36956706 for point 18/110
# Found nearest node 36956706 for point 19/110
# Found nearest node 36956706 for point 20/110
# Found nearest node 36956706 for point 21/110
# Found nearest node 36956706 for point 22/110
# Found nearest node 36926678 for point 23/110
# Found nearest node 36926678 for point 24/110
# Found nearest node 36926678 for point 25/110
110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 2/110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 3/110: 36982363
# Successfully created isochrone for node 36982363
# Processing node 4/110: 36982363
# Successfully created isochrone for node 36982363
# Processing node 5/110: 36982363
# Successfully created isochrone for node 36982363
# Processing node 6/110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 7/110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 8/110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 9/110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 10/110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 11/110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 12/110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 13/110: 36960897
# Successfully created isochrone for node 36960897
# Processing node 14/110: 36960897
# Successfully created isochrone for node 36960897
# Processing node 15/110: 36926678
# Successfully created isochrone for node 36926678
# Processing node 16/110: 36956706
# Successfully created isochrone for node 36956706
# Processing node 17/110: 36926678
# Successfully created isochrone for node 36926678
# Processing node 18/110: 36956706
# Successfully created isochrone for node 36956706
# Processing node 19/110: 36956706
# Successfully created isochrone for node 36956706
# Processing node 20/110: 36956706
# Successfully created isochrone for node 36956706
# Processing node 21/110: 36956706
# Successfully created isochrone for node 36956706
# Processing node 22/110: 36956706
# Successfully created isochrone for node 36956706
# Processing node 23/110: 36926678
# Successfully created isochrone for node 36926678
# Processing node 24/110: 36926678
# Successfully created isochrone for node 36926678
# Processing node 25/110: 36926678
# Successfully created isochrone for node 36926678
# Processing node 26/110: 36926678
# Successfully created isochrone for node 36926678
# Processing node 27/110: 36926675
# Successfully created isochrone for node 36926675
# Processing node 28/110: 36956706
# Successfully created isochrone for node 36956706
# Processing node 29/110: 36926675
# Successfully created isochrone for node 36926675
# Processing node 30/110: 36982363
# Successfully created isochrone for node 36982363
# Processing node 31/110: 36956706
# Successfully created isochrone for node 36956706
# Processing node 32/110: 36956706
# Successfully created isochrone for node 36956706
# Processing node 33/110: 36956706
# Successfully created isochrone for node 36956706
# Processing node 34/110: 36982363
# Successfully created isochrone for node 36982363
# Processing node 35/110: 36982363
# Successfully created isochrone for node 36982363
# Processing node 36/110: 36982363
# Successfully created isochrone for node 36982363
# Processing node 37/110: 36982363
# Successfully created isochrone for node 36982363
# Processing node 38/110: 36956706
# Successfully created isochrone for node 36956706
# Processing node 39/110: 36956706
# Successfully created isochrone for node 36956706
# Processing node 40/110: 36982363
# Successfully created isochrone for node 36982363
# Processing node 41/110: 36926675
# Successfully created isochrone for node 36926675
# Processing node 42/110: 36936090
# Successfully created isochrone for node 36936090
# Processing node 43/110: 36936090
# Successfully created isochrone for node 36936090
# Processing node 44/110: 36926675
# Successfully created isochrone for node 36926675
# Processing node 45/110: 36936090
# Successfully created isochrone for node 36936090
# Processing node 46/110: 36936090
# Successfully created isochrone for node 36936090
# Processing node 47/110: 36936090
# Successfully created isochrone for node 36936090
# Processing node 48/110: 36936090
# Successfully created isochrone for node 36936090
# Processing node 49/110: 36936090
# Successfully created isochrone for node 36936090
# Processing node 50/110: 36936094
# Successfully created isochrone for node 36936094
# Processing node 51/110: 36926678
# Successfully created isochrone for node 36926678
# Processing node 52/110: 36926678
# Successfully created isochrone for node 36926678
# Processing node 53/110: 6015443225
# Not enough points (2) to create polygon for node 6015443225
# Processing node 54/110: 6015443225
# Not enough points (2) to create polygon for node 6015443225
# Processing node 55/110: 36936090
# Successfully created isochrone for node 36936090
# Processing node 56/110: 36936090
# Successfully created isochrone for node 36936090
# Processing node 57/110: 36936090
# Successfully created isochrone for node 36936090
# Processing node 58/110: 36936090
# Successfully created isochrone for node 36936090
# Processing node 59/110: 36936090
# Successfully created isochrone for node 36936090
# Processing node 60/110: 36936090
# Successfully created isochrone for node 36936090
# Processing node 61/110: 36982363
# Successfully created isochrone for node 36982363
# Processing node 62/110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 63/110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 64/110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 65/110: 36960897
# Successfully created isochrone for node 36960897
# Processing node 66/110: 36960897
# Successfully created isochrone for node 36960897
# Processing node 67/110: 36960897
# Successfully created isochrone for node 36960897
# Processing node 68/110: 36960897
# Successfully created isochrone for node 36960897
# Processing node 69/110: 36960897
# Successfully created isochrone for node 36960897
# Processing node 70/110: 36938725
# Successfully created isochrone for node 36938725
# Processing node 71/110: 36963444
# Successfully created isochrone for node 36963444
# Processing node 72/110: 36939345
# Not enough points (2) to create polygon for node 36939345
# Processing node 73/110: 36939345
# Not enough points (2) to create polygon for node 36939345
# Processing node 74/110: 36939345
# Not enough points (2) to create polygon for node 36939345
# Processing node 75/110: 36939345
# Not enough points (2) to create polygon for node 36939345
# Processing node 76/110: 36908376
# Successfully created isochrone for node 36908376
# Processing node 77/110: 36951943
# Successfully created isochrone for node 36951943
# Processing node 78/110: 36951943
# Successfully created isochrone for node 36951943
# Processing node 79/110: 36908376
# Successfully created isochrone for node 36908376
# Processing node 80/110: 36908376
# Successfully created isochrone for node 36908376
# Processing node 81/110: 36991288
# Successfully created isochrone for node 36991288
# Processing node 82/110: 36925621
# Successfully created isochrone for node 36925621
# Processing node 83/110: 36925621
# Successfully created isochrone for node 36925621
# Processing node 84/110: 36925621
# Successfully created isochrone for node 36925621
# Processing node 85/110: 36927036
# Successfully created isochrone for node 36927036
# Processing node 86/110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 87/110: 36982363
# Successfully created isochrone for node 36982363
# Processing node 88/110: 36982363
# Successfully created isochrone for node 36982363
# Processing node 89/110: 36982363
# Successfully created isochrone for node 36982363
# Processing node 90/110: 36982363
# Successfully created isochrone for node 36982363
# Processing node 91/110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 92/110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 93/110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 94/110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 95/110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 96/110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 97/110: 36960892
# Successfully created isochrone for node 36960892
# Processing node 98/110: 36925558
# Successfully created isochrone for node 36925558
# Processing node 99/110: 36925558
# Successfully created isochrone for node 36925558
# Processing node 100/110: 7162242372
# Not enough points (2) to create polygon for node 7162242372
# Processing node 101/110: 36925558
# Successfully created isochrone for node 36925558
# Processing node 102/110: 7162242372
# Not enough points (2) to create polygon for node 7162242372
# Processing node 103/110: 7162242372
# Not enough points (2) to create polygon for node 7162242372
# Processing node 104/110: 7162242372
# Not enough points (2) to create polygon for node 7162242372
# Processing node 105/110: 7162242372
# Not enough points (2) to create polygon for node 7162242372
# Processing node 106/110: 36925558
# Successfully created isochrone for node 36925558
# Processing node 107/110: 7162242372
# Not enough points (2) to create polygon for node 7162242372
# Processing node 108/110: 10739921333
# Not enough points (2) to create polygon for node 10739921333
# Processing node 109/110: 10739921333
# Not enough points (2) to create polygon for node 10739921333
# Processing node 110/110: 36927053
# Successfully created isochrone for node 36927053
# Saved 96 isochrones to C:/Users/weckero/Documents/isochrones_points.shp
# C:\Users\weckero\AppData\Local\Temp\ipykernel_18256\1118106271.py:168: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   isochrones_gdf.to_file(isochrones_output)
# C:\Users\weckero\AppData\Roaming\Python\Python311\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'travel_mins' to 'travel_min'
#   ogr_write(

# %%
import osmnx as ox
import geopandas as gpd
import os

# 1. Load the GraphML file (using OSMnx)
downloads_path = os.path.join(os.path.expanduser("~"), "Downloads")
graph = ox.load_graphml(os.path.join(downloads_path, "oregon_drive_network_projected.graphml"))
graph_proj = ox.project_graph(graph)

# 2. Load Point Data
basefolder = "C:/Users/weckero/Documents/"
points_gdf = gpd.read_file(basefolder + "clipped_tester.shp")
points_gdf = points_gdf.to_crs(graph_proj.graph['crs'])

# 3. Find nearest nodes
nearest_nodes = ox.distance.nearest_nodes(
    G=graph_proj,
    X=points_gdf.geometry.x,
    Y=points_gdf.geometry.y,
)

# 4. Generate Isochrones
travel_time = 600  # 10 minutes
isochrones_list = []

for i, node in enumerate(nearest_nodes):
    try:
        isochrone_polygon = ox.get_polygon(
            G=graph_proj,
            polygon=ox.distance.extended_isochrone_polygons(
                G=graph_proj,
                center_node=node,
                dist=travel_time,
                edge_buff=2.5,
                node_buff=0.5,
                circ_dist=1000,
                num_circles=6,
            ),
        )
        isochrone_gdf = gpd.GeoDataFrame(
            geometry=[isochrone_polygon], crs=graph_proj.graph['crs']
        )

        # Add point attributes
        if i < len(points_gdf):
            for col in points_gdf.columns:
                if col != 'geometry':
                    isochrone_gdf[col] = points_gdf.iloc[i][col]

        isochrones_list.append(isochrone_gdf)
        print(f"Successfully created isochrone for node {node}")

    except Exception as e:
        print(f"Error creating isochrone for node {node}: {e}")

# 5. Combine all isochrones into a single GeoDataFrame
if isochrones_list:
    try:
        isochrones_gdf = gpd.pd.concat(isochrones_list)
        isochrones_output = os.path.join(basefolder, "isochrones_points2.shp")
        isochrones_gdf.to_file(isochrones_output)
        print(f"Saved {len(isochrones_list)} isochrones to {isochrones_output}")
    except Exception as e:
        print(f"Error combining/saving isochrones: {e}")
else:
    print("No isochrones were created successfully.")
# Out:
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36982363: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36982363: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36982363: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960897: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960897: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36926678: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36956706: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36926678: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36956706: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36956706: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36956706: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36956706: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36956706: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36926678: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36926678: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36926678: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36926678: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36926675: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36956706: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36926675: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36982363: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36956706: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36956706: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36956706: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36982363: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36982363: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36982363: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36982363: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36956706: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36956706: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36982363: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36926675: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36936090: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36936090: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36926675: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36936090: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36936090: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36936090: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36936090: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36936090: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36936094: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36926678: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36926678: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 6015443225: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 6015443225: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36936090: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36936090: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36936090: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36936090: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36936090: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36936090: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36982363: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960897: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960897: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960897: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960897: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960897: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36938725: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36963444: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36939345: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36939345: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36939345: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36939345: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36908376: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36951943: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36951943: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36908376: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36908376: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36991288: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36925621: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36925621: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36925621: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36927036: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36982363: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36982363: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36982363: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36982363: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36960892: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36925558: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36925558: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 7162242372: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36925558: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 7162242372: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 7162242372: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 7162242372: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 7162242372: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36925558: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 7162242372: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 10739921333: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 10739921333: module 'osmnx' has no attribute 'get_polygon'
# Error creating isochrone for node 36927053: module 'osmnx' has no attribute 'get_polygon'
# No isochrones were created successfully.
